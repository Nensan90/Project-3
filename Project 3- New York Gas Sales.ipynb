# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np

# %%
# Set x axis and variable
x = [5639889, 5678637, 5808184, 5880701, 5829696, 5755012, 5784552, 5739459, 5634402, 5644564, 5781480, 5548356, 5424144, 5373436, 5561069, 5520551]
y = [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015]

# %%
# Draw a scatter plot  with 0.50 transparency
plt.scatter (x, y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Set a Title and labels
plt.title("Gas Sold per Year in Gallons in New York")
plt.xlabel("Average Gallons Sold (millions)")
plt.ylabel("Year")
# Out:
# Text(29.222222222222214, 0.5, 'Year')
